# %% [markdown]
# #**Prediction using Supervised ML**
#
# To Predict the percentage of an student based on the no. of study hours.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# ##**Import the Dataset**

# %%
student_scores=pd.read_csv(r'https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv')
student_scores_df=pd.DataFrame(data)

# %% [markdown]
# ##**Printing the head of the dataframe**

# %%
student_scores_df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# #**Visualising the Dataset**
#
# From the figure it is visible that score is proportional to the number of hours of study

# %%
sns.set_style("darkgrid")
with sns.color_palette('Blues_d'):
       plot=sns.lmplot("Hours","Scores",data=student_scores_df,scatter_kws={'s':20})
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #**Training and Testing Data**
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets. Setting variable X equal to the number of hours of study & variable Y equal to the scores.

# %%
X=student_scores_df[['Hours']]
Y=student_scores_df['Scores']

# %% [markdown]
# **Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Setting test_size=0.3 and random_state=42**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# #**Training the Model**
# Now its time to train our model on our training data!

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model=LinearRegression()
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Print the Coeffficients/weights of the model**
#
# expected size is 1x1 since ip is Nx1 & op is Nx1

# %%
print(linear_model.coef_)
# Out:
# [9.71054094]

# %% [markdown]
# #**Predicting Test Data**
# Now that we have fit our model, let's evaluate its performance by predicting off the test values

# %%
predictions=linear_model.predict(X_test)

# %%
print(predictions)
# Out:
# [83.39168645 27.07054902 27.07054902 69.79692914 60.0863882  29.0126572
#  34.83898177 52.31795545]

# %%
plt.subplot(1,2,1)
plt.scatter(X_test,y_test)
plt.xlabel('x_test')
plt.ylabel('y_test')
plt.xlim([0,10])
plt.ylim([0,100])
plt.subplot(1,2,2)
plt.scatter(X_test,predictions)
plt.xlabel('x_test')
plt.ylabel('predictions')
plt.xlim([0,10])
plt.ylim([0,100])
plt.xlabel('x_test')
plt.subplots_adjust(wspace=0.4)

# %% [markdown]
# ###**What will be predicted score if a student studies for 9.25 hrs/ day?**

# %%
print(linear_model.predict([[9.25]]))
# Out:
# [92.61670034]

# %% [markdown]
# *A student studying 9.25hrs/day can expect 92.6%*
